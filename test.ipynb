# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Desktop\real-estate\data\real-estate-raw.csv")
df.columns
# Out:
# Index(['listing_id', 'property_type', 'country', 'city', 'neighborhood',
#        'surface_m2', 'num_rooms', 'num_bathrooms', 'floor', 'year_built',
#        'price', 'listing_date', 'condition', 'heating_type', 'parking',
#        'energy_rating'],
#       dtype='object')

# %%
df.shape
# Out:
# (2060, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2060 entries, 0 to 2059
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     2060 non-null   int64
#  1   property_type  2060 non-null   object
#  2   country        1817 non-null   object
#  3   city           2060 non-null   object
#  4   neighborhood   1810 non-null   object
#  5   surface_m2     1878 non-null   float64
#  6   num_rooms      1932 non-null   float64
#  7   num_bathrooms  1947 non-null   float64
#  8   floor          1944 non-null   float64
#  9   year_built     1873 non-null   float64
#  10  price          2060 non-null   object
#  11  listing_date   2060 non-null   object
#  12  condition      1649 non-null   object
#  13  heating_type   1813 non-null   object
#  14  parking        1806 non-null   object
#  15  energy_rating  1840 non-null   object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 257.6+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(60)

# %%
df.dtypes
# Out:
# listing_id         int64
# property_type     object
# country           object
# city              object
# neighborhood      object
# surface_m2       float64
# num_rooms        float64
# num_bathrooms    float64
# floor            float64
# year_built       float64
# price             object
# listing_date      object
# condition         object
# heating_type      object
# parking           object
# energy_rating     object
# dtype: object

# %%
df.head()
# Out:
#    listing_id property_type      country       city neighborhood  surface_m2  \
# 0        1665        studio      Germany     Berlin      SUBURBS       287.0
# 1        1870         house          NaN     Naples          NaN       378.0
# 2        1415        Villa        France       Lyon      SUBURBS       277.0
# 3        1504        Villa   Netherlands  Amsterdam      Suburbs       245.0
# 4        2333         house        Spain   Valencia  City Center        94.0
#
#    num_rooms  num_bathrooms  floor  year_built    price listing_date  \
# 0        6.0            2.0    1.0      1984.0   230376   2023-03-12
# 1        3.0            4.0   17.0      1973.0  1856023   2022-10-25
# 2        8.0            3.0    5.0      1980.0   710838   06/02/2020
# 3        2.0            4.0   14.0      1953.0  1869348   2019-01-16
# 4        4.0            2.0    8.0      2005.0  1836672   2023-12-03
#
#   condition heating_type parking energy_rating
# ...

# %%
df["property_type"].unique()
# Out:
# array([' studio', 'house', 'Villa ', 'duplex', 'apartment', 'HOUSE',
#        'Penthouse', 'VILLA', 'APT'], dtype=object)
